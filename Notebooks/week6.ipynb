# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
df = pd.read_csv("../data/pre_proccesed_data.csv")
df
# Out:
#        age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0       50       2     168    62.0    110     80            1     1      0
# 1       55       1     156    85.0    140     90            3     1      0
# 2       51       1     165    64.0    130     70            3     1      0
# 3       48       2     169    82.0    150    100            1     1      0
# 4       47       1     156    56.0    100     60            1     1      0
# ...    ...     ...     ...     ...    ...    ...          ...   ...    ...
# 68008   52       2     168    76.0    120     80            1     1      1
# 68009   61       1     158   126.0    140     90            2     2      0
# 68010   52       2     183   105.0    180     90            3     1      0
# 68011   61       1     163    72.0    135     80            1     2      0
# 68012   56       1     170    72.0    120     80            2     1      0
#
#        alco  active  cardio
# 0         0       1       0
# 1         0       1       1
# 2         0       0       1
# 3         0       1       1
# 4         0       0       0
# ...     ...     ...     ...
# 68008     0       1       0
# 68009     0       1       1
# 68010     1       0       1
# 68011     0       0       1
# 68012     0       1       0
#
# [68013 rows x 12 columns]

# %%
df.hist(bins=25, figsize=(25, 21))
plt.suptitle('Histograms of Numerical Features')
plt.show()
